# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

# %% [markdown]
# ## **Previous Application Feature Engineering**

# %%
df_prev = pd.read_csv('../input/home-credit-default-risk/previous_application.csv')

# %%
df_prev.shape
# Out:
# (1670214, 37)

# %%
#Drop unnecessary columns & high percentage of null values columns

drop_list = ['AMT_DOWN_PAYMENT', 'SELLERPLACE_AREA', 'CNT_PAYMENT', 'PRODUCT_COMBINATION', 'DAYS_FIRST_DRAWING', 'DAYS_FIRST_DUE',
                'DAYS_LAST_DUE_1ST_VERSION', 'DAYS_LAST_DUE','DAYS_TERMINATION','NFLAG_INSURED_ON_APPROVAL','RATE_INTEREST_PRIMARY', 'RATE_INTEREST_PRIVILEGED']
df_prev.drop(drop_list, axis = 1, inplace = True)

# %%
df_prev.shape
# Out:
# (1670214, 25)

# %%
df_prev.to_csv('previous_application_new.csv', index=False)

# %% [markdown]
# # **POS Cash Balance Feature Engineering**

# %%
pos = pd.read_csv('../input/home-credit-default-risk/POS_CASH_balance.csv')

# %%
pos.shape
# Out:
# (10001358, 8)

# %%
pos.head()
# Out:
#    SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 0     1803195      182943             -31            48.0
# 1     1715348      367990             -33            36.0
# 2     1784872      397406             -32            12.0
# 3     1903291      269225             -35            48.0
# 4     2341044      334279             -35            36.0
#
#    CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 0                   45.0               Active       0           0
# 1                   35.0               Active       0           0
# 2                    9.0               Active       0           0
# 3                   42.0               Active       0           0
# 4                   35.0               Active       0           0

# %%
pos.to_csv('POS_CASH_balance_new.csv', index=False)
